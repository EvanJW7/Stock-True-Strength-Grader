# %%
import requests
from bs4 import BeautifulSoup
from sympy import per
import yfinance as yf
import pandas as pd
import numpy as np

stocks = ['AAPL', 'MSFT', 'TSLA', 'XOM', 'OXY', 'SQ', 'PLTR', 'NVDA', 'KR', 'WMT', 'MCD', 'JPM', 'GS', 'SLB', 'NEX',
         'NUE', 'JNJ', 'MA', 'DDOG', 'MU', 'GOOGL', 'AMZN', 'TDOC', 'KOS', 'ROKU']
          
PFA = []
v = []
score = []
stockslist = []
industry = []
market_cap = []
short_float = []

for stock in stocks:
    ticker = yf.Ticker(stock)
    current_price = ticker.info['currentPrice']
    ATH = ticker.info['fiftyTwoWeekHigh']
    percent_from_ATH = round((1 - current_price/ATH)*100, 2)
    PFA.append(percent_from_ATH)
    url = f'https://www.alphaquery.com/stock/{stock}/volatility-option-statistics/180-day/historical-volatility'
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'lxml')
    volatility = soup.findAll('div', class_ = "indicator-figure-inner")[0]
    vol = float(volatility.text)*100
    vol = round(vol, 2)
    v.append(vol)
    mkcp = ticker.info['marketCap']
    if mkcp == None:
        mkcp = 0
    market_cap.append(round(mkcp/1000000000))
    stockslist.append(stock)
    sector = ticker.info['sector']
    industry.append(sector)
    shorts = ticker.info['shortPercentOfFloat']
    if shorts == None:
        shorts = 0
    shorts = float(shorts*100)
    shorts = round(shorts, 2)
    short_float.append(shorts)
    strength_score = ((0-percent_from_ATH + (vol/2))/2 + (shorts/5))/2 
    strength_score = round(strength_score, 2)
    score.append(round(strength_score, 1))
        
data = {'Stock': stockslist,
        'Industry': industry,
        'Market Cap (B)': market_cap,
        '% Float Short': short_float,
        '% From 52w High': PFA,
        'Volatility': v,
        'Strength Score': score}

df = pd.DataFrame(data)
df = df.sort_values(by='Strength Score', ascending=False)
df.reset_index(drop = True, inplace=True)
df.index = np.arange(1, len(df)+1)
df

#Current date: 3/5/22
# Out:
#     Stock                Industry  Market Cap (B)  % Float Short  \
# 1     KOS                  Energy               3           6.47
# 2     NEX                  Energy               2           2.58
# 3     OXY                  Energy              52           5.72
# 4     NUE         Basic Materials              40           3.24
# 5      KR      Consumer Defensive              43           4.16
# 6     XOM                  Energy             358           1.08
# 7     SLB                  Energy              55           1.53
# 8      MU              Technology              92           2.15
# 9    DDOG              Technology              44           5.24
# 10    JNJ              Healthcare             446           0.58
# 11    WMT      Consumer Defensive             396           0.89
# 12   AAPL              Technology            2677           0.69
# 13  GOOGL  Communication Services            1751           0.69
# 14   TSLA       Consumer Cyclical             842           3.16
# 15     MA      Financial Services             325           0.69
# 16   MSFT              Technology            2176           0.57
# 17    MCD       Consumer Cyclical             176           0.88
# 18   AMZN       Consumer Cyclical            1477           0.82
# 19   NVDA              Technology             572           0.97
# 20     GS      Financial Services             110           1.48
# 21    JPM      Financial Services             407           0.57
# 22     SQ              Technology              49          10.56
# 23   PLTR              Technology              22           6.61
# 24   TDOC              Healthcare              11          15.87
# 25   ROKU  Communication Services              16           5.14
#
#     % From 52w High  Volatility  Strength Score
# 1              0.62       76.58            10.1
# 2              2.53       72.57             8.7
# 3              0.46       56.34             7.5
# 4              1.09       45.78             5.8
# 5              0.07       39.91             5.4
# 6              0.22       27.47             3.5
# 7              8.68       39.50             2.9
# 8             16.80       42.05             1.3
# 9             28.79       61.83             1.1
# 10             5.80       16.40             0.7
# 11             6.39       17.63             0.7
# 12            10.81       25.80             0.6
# 13            12.96       27.90             0.3
# 14            32.59       62.08            -0.1
# 15            17.62       34.28            -0.1
# 16            17.10       26.48            -0.9
# 17            13.03       15.43            -1.2
# 18            22.80       35.13            -1.2
# 19            33.80       55.70            -1.4
# 20            22.64       27.77            -2.0
# 21            22.29       25.65            -2.3
# 22            63.17       70.46            -5.9
# 23            62.58       60.95            -7.4
# 24            67.61       61.75            -7.6
# 25            75.24       78.54            -8.5
